# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns
iris = load_iris()
target_names = iris.target_names
Iris = pd.DataFrame(data=iris['data'], columns=iris.feature_names)
new_column = iris.target
new_column = [target_names[i] for i in new_column]
Iris['Species'] = new_column
Iris = shuffle(Iris)
Iris.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 37                 4.9               3.1                1.5               0.1
# 77                 6.7               3.0                5.0               1.7
# 79                 5.7               2.6                3.5               1.0
# 85                 6.0               3.4                4.5               1.6
# 137                6.4               3.1                5.5               1.8
#
#         Species
# 37       setosa
# 77   versicolor
# 79   versicolor
# 85   versicolor
# 137   virginica

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 37 to 99
# Data columns (total 5 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# Species              150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
sns.set(font_scale=1.25)
sns.set_style(style='whitegrid')
sns.FacetGrid(Iris, hue='Species', height=5, aspect=2.5).map(plt.scatter, 'sepal length (cm)', 'sepal width (cm)').add_legend()
sns.FacetGrid(Iris, hue='Species', height=5, aspect=2.5).map(plt.scatter, 'petal length (cm)', 'petal width (cm)').add_legend()

# %%
X = iris.data
y = iris.target

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
knn = KNeighborsClassifier(n_neighbors=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
knn.fit(X_train, y_train)

pred = knn.predict(X_test)
print("Accuracy on test set:{}".format(accuracy_score(y_test, pred)))
print(60*"#")
print(classification_report(y_test, pred))
# Out:
# Accuracy on test set:1.0
# ############################################################
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        17
#           1       1.00      1.00      1.00        13
#           2       1.00      1.00      1.00        20
#
# avg / total       1.00      1.00      1.00        50
